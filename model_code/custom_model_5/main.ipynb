# %%
# from mobile_net import get_model
import librosa
import tensorflow as tf
import glob
import numpy as np
import random
import wave
import os
import pickle
# import noisereduce as nr
import requests

# %%
gpus = tf.config.list_physical_devices('GPU')
gpu = gpus[0]
tf.config.experimental.set_memory_growth(gpu, True)
tf.config.list_logical_devices('GPU')
# Out:
# 2024-09-09 04:45:01.257583: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43629 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:8b:00.0, compute capability: 8.9
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
noise_path = '/shareddrive/working/data_code/data/neg_data/_background_noise_/chunks/2-5s_chunks/*'
environment_path = '/shareddrive/working/data_code/data/neg_data/envornment/chunks/2-5s_chunks/*'
word_path = '/shareddrive/working/data_code/data/neg_data/spcmd/all_words/2-5s_chunks/*'
recording_path = '/shareddrive/working/data_code/data/neg_data/internet_recordings/chunks/2-5s_chunks/*'

# %%
word_files = glob.glob(word_path)
environment_files = glob.glob(environment_path)
noise_files = glob.glob(noise_path)
recording_files = glob.glob(recording_path)
len(environment_files),len(noise_files),len(word_files),len(recording_files)
# Out:
# (515, 264, 64721, 2324)

# %%
def get_duration(audio_path):
    with wave.open(audio_path, 'rb') as wav_file:
        sample_rate = wav_file.getframerate()
        num_frames = wav_file.getnframes()
        duration = num_frames / sample_rate
    return duration

# %%
limit = 1.5
# adele_path = '/shareddrive/working/data_code/data/adele/augmented/*'
# adele_folders = glob.glob(adele_path)
# adele_files = [j for i in adele_folders for j in glob.glob(f'{i}/*')]
# adele_files = [j for i in adele_folders for j in glob.glob(f'{i}/*') if get_duration(j) <= limit]
hilfe_path = '/shareddrive/working/data_code/data/hilfe_hilfe/augmented/*'
hilfe_folders = glob.glob(hilfe_path)
hilfe_files = [j for i in hilfe_folders for j in glob.glob(f'{i}/*')]
# # hilfe_files = [j for i in hilfe_folders for j in glob.glob(f'{i}/*') if get_duration(j) <= limit]

# %%
len(hilfe_files)
# Out:
# 10935

# %%
# DEEPGRAM_API_KEY = '4207b8a639744fbdbe634616684bf7d67c8791e2'
# url = 'https://api.deepgram.com/v1/listen'
# headers = {
#     'Authorization': f'Token {DEEPGRAM_API_KEY}',
#     'Content-Type': 'audio/wav'
# }
# params = {
#     'language': 'de',  # Specify the language as German
#     'tier': 'enhanced',  # Use the enhanced tier for better accuracy
#     'model': 'general'  # Specify the model
# }
# ad_files = list()
# for i in adele_files:
#     # Read the audio file
#     with open(i, 'rb') as audio_file:
#         response = requests.post(url, headers=headers, params=params, data=audio_file)

#     if response.status_code == 200:
#         if 'adele' in response.json()['results']['channels'][0]['alternatives'][0]['transcript']:
#             ad_files.append(i)
#     else:
#         print("Error:", response.json())
# len(ad_files)

# %%
no_of_files = 1109+660
file_path_and_labels = list()
# file_path_and_labels.extend([(i,1) for i in random.sample(adele_files,no_of_files)])
# file_path_and_labels.extend([(i,1) for i in adele_files])
# file_path_and_labels.extend([(i,1) for i in random.sample(hilfe_files,no_of_files)])
file_path_and_labels.extend([(i,1) for i in hilfe_files])
# avg_files = (len(adele_files) + len(hilfe_files)) // 2
avg_files = len(hilfe_files)
# file_path_and_labels.extend([(i,0) for i in random.sample(recording_files,len(recording_files)//2)])
file_path_and_labels.extend([(i,0) for i in random.sample(word_files,avg_files)])
file_path_and_labels.extend([(i,0) for i in noise_files])
file_path_and_labels.extend([(i,0) for i in environment_files])
random.shuffle(file_path_and_labels)
# avg_files

# %%
avg_files-len(recording_files)//2
# Out:
# 9773

# %%
sr = 16000
max_seconds = 2.5
pad_or_trunc = lambda a,i : a[0:i] if len(a) > i else a if len(a) == i else np.pad(a,(0, (i-len(a))))

def process_data(y,sr,max_seconds):
    y = pad_or_trunc(y,sr*max_seconds)
    features = librosa.feature.melspectrogram(y=y,sr=sr,n_fft=1024)
    return features
    
def get_processed_data(audio_file):
    y,_ = librosa.load(audio_file,sr=sr)
    # y = nr.reduce_noise(y=y, sr=sr,n_fft=1024)
    # y[np.isnan(y)] = 0
    features = process_data(y,sr,max_seconds)
    return features
try:
    with open('f_and_ls.pickle','rb') as f:
        features_and_labels = pickle.load(f)
except:
    features_and_labels = list()
    for i,j in file_path_and_labels:
        try:
            features = get_processed_data(i)
            features_and_labels.append((features,j))
        except Exception as e: 
            print(i)
            print(e)
        # features = get_processed_data(i)
        # features_and_labels.append(features,j)
    # with open('f_and_l.pickle','wb') as f:
    #     pickle.dump(features_and_labels,f)
finally:
    print(features_and_labels[0][0].shape)
# Out:
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_607.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_567.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_683.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_112.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_61.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_466.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_302.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_605.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_0.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_709.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_92.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_617.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_562.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_728.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_34.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_731.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_590.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_261.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_12.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_599.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_113.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_626.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_197.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_526.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_389.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_107.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_458.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_97.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_7.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_427.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_574.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_236.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_261.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_636.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_719.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_729.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_98.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_204.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_355.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_322.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_432.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_491.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_278.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_12.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_359.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_652.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_419.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_47.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_29.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_284.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_568.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_598.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_255.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_515.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_331.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_318.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_409.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_536.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_223.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_215.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_102.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_674.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_52.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_639.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_725.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_639.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_294.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_122.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_173.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_259.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_80.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_657.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_699.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_228.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_122.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_557.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_103.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_734.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_544.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_99.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_598.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_170.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_358.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_233.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_270.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_464.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_376.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_50.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_311.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_476.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_301.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_307.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_731.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_32.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_276.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_297.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_236.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_14.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_219.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_312.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_442.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_564.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_743.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_318.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_140.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_540.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_688.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_177.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_54.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_118.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_33.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_734.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_65.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_414.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_10.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_423.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_304.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_532.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_716.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_162.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_211.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_133.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_607.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_421.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_257.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_645.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_549.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_221.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_232.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_188.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_110.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_598.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_489.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_700.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_216.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_220.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_372.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_224.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_166.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_642.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_561.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_651.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_587.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_597.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_684.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_569.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_414.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_582.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_240.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_424.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_271.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_702.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_194.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_497.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_725.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_572.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_665.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_267.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_565.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_665.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_387.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_543.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_595.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_602.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_426.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_177.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_491.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_596.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_260.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_133.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_26.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_242.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_407.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_368.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_145.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_612.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_258.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_455.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_115.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_221.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_313.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_477.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_382.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_608.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_307.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_340.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_171.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_567.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_287.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_129.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_150.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_237.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_375.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_78.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_323.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_107.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_559.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_295.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_375.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_694.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_609.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_192.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_17.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_697.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_51.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_191.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_723.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_206.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_498.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_510.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_66.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_663.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_707.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_375.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_201.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_576.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_599.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_421.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_471.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_725.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_296.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_652.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_445.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_698.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_375.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_233.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_171.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_469.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_10.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_412.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_462.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_607.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_326.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_136.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_131.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_101.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_79.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_344.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_498.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_542.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_92.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_526.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_698.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_147.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_99.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_731.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_454.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_157.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_469.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_597.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_659.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_738.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_288.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_137.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_448.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_14.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_371.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_231.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_467.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_488.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_115.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_stop/bs_Hilfe_Hilfe_260.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_692.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_503.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/seven_band_parameter/sbp_Hilfe_Hilfe_78.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_176.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_382.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_369.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/bit_crush/bc_Hilfe_Hilfe_2.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/pitch_shift/ps_Hilfe_Hilfe_121.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_495.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/room_simulator/rs_Hilfe_Hilfe_559.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_660.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_643.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_197.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_313.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/percentile/Hilfe_Hilfe_694.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_185.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe_304.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_406.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_527.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/high_shelf_filter/hsf_Hilfe_Hilfe
wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_629.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/gain_transition/gt_Hilfe_Hilfe_346.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/normalize/n_Hilfe_Hilfe_616.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/mp3_compression/mp3c_Hilfe_Hilfe_548.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_382.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_310.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/emphesis/pe_Hilfe_Hilfe_357.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/polarity_inversion/pi_Hilfe_Hilfe_188.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/neg_emphesis/pne_Hilfe_Hilfe_703.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/band_pass/bp_Hilfe_Hilfe_300.wav
# /shareddrive/working/data_code/data/hilfe_hilfe/augmented/low_shelf_filter/lsf_Hilfe_Hilfe_40.wav

# %%
class DataSequenceRaw(tf.keras.utils.Sequence):

    def __init__(self,data,batch_size):
        self.data_size = len(data)
        audios,labels = zip(*data)
        self.X = np.array(audios)
        self.Y = np.array(labels)
        self.batch_size = batch_size

        
    def __len__(self):
        return int(np.ceil(self.data_size / self.batch_size))

    def __getitem__(self,idx):
        s = idx * self.batch_size
        e = (idx + 1) * self.batch_size
        X = self.X[s:e]
        Y = self.Y[s:e]
        return X,Y

# %%
def _get_train_val_size(total_examples,train_percent=70):
    
    train_ratio = round(train_percent)/100
    remaining_percent = 100 - train_percent
    test_percent = round(remaining_percent/3)*2
    val_percent = remaining_percent - test_percent
    val_ratio = val_percent/100
    train_size = round(total_examples * train_ratio)
    val_size = round(total_examples * val_ratio)
    return train_size,val_size

def get_data_raw(data,train_percent=70,batch_size=32):

    train_size,val_size = _get_train_val_size(len(data),train_percent)

    train_examples = data[:train_size]
    val_examples = data[train_size:train_size+val_size]
    test_examples = data[train_size+val_size:]

    train = DataSequenceRaw(train_examples,batch_size=batch_size)
    test = DataSequenceRaw(test_examples,batch_size=1)
    val = DataSequenceRaw(val_examples,batch_size=batch_size)

    return train,test,val

train,test,val = get_data_raw(features_and_labels,train_percent=80)

# %%
shape = train[0][0][0].shape
input_shape = [*shape,1]

# %%
def get_model(
        input_shape,
        output_neurons=1,
        output_activation='sigmoid',
        loss=tf.keras.losses.binary_crossentropy,
        lr=0.0001
):
    _input = tf.keras.layers.Input(shape=input_shape)
    x = tf.keras.layers.Conv2D(512,kernel_size=3,padding='valid',activation='relu')(_input)
    x = tf.keras.layers.MaxPool2D((2,2))(x)
    x = tf.keras.layers.Conv2D(256,kernel_size=3,padding='valid',activation='relu')(x)
    x = tf.keras.layers.MaxPool2D((2,2))(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(1024,activation='relu')(x)
    x = tf.keras.layers.Dense(1024,activation='relu')(x)
    x = tf.keras.layers.Dropout(0.7)(x)
    x = tf.keras.layers.Dense(1024,activation='relu')(x)
    x = tf.keras.layers.Dense(512,activation='relu')(x)
    x = tf.keras.layers.Dense(10,activation='relu')(x)
    outputs = tf.keras.layers.Dense(output_neurons,activation=output_activation,kernel_regularizer=tf.keras.regularizers.L2(l2=0.01))(x)
    model = tf.keras.Model(inputs=_input,outputs=outputs)

    model.compile(
        loss=loss,
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        metrics=['accuracy'],
    )

    return model

model = get_model(
        input_shape=input_shape,
        lr=0.001
)

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy',factor=0.1,patience=5,mode='max')
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=1,mode='max',restore_best_weights=True,start_from_epoch=10)
with tf.device('/gpu'):
    history = model.fit(train,epochs=100,validation_data=val,verbose=1,callbacks=[reduce_lr,early_stopping])

# %%
model.evaluate(test)

# %%
folder_path = '/shareddrive/working/model_code/models/custom_model_5/trail_1'
os.makedirs(folder_path,exist_ok=True)
model_path = f'{folder_path}/16k_melspec-nfft-1024_a_cnn_dense_model.keras'
model.save(model_path)
